# %%
import numpy as np
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt
from scipy.stats import linregress

# %%
BTC = yf.download('BTC-USD', start='2022-12-24', end='2022-12-25',  interval = '1m')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
BTC
# Out:
#                                    Open          High           Low  \
# Datetime
# 2022-12-24 00:00:00+00:00  16796.976562  16796.976562  16796.976562
# 2022-12-24 00:01:00+00:00  16797.513672  16797.513672  16797.513672
# 2022-12-24 00:02:00+00:00  16797.535156  16797.535156  16797.535156
# 2022-12-24 00:03:00+00:00  16797.552734  16797.552734  16797.552734
# 2022-12-24 00:04:00+00:00  16794.287109  16794.287109  16794.287109
# ...                                 ...           ...           ...
# 2022-12-24 23:55:00+00:00  16848.976562  16848.976562  16848.976562
# 2022-12-24 23:56:00+00:00  16848.990234  16848.990234  16848.990234
# 2022-12-24 23:57:00+00:00  16849.703125  16849.703125  16849.703125
# 2022-12-24 23:58:00+00:00  16847.953125  16847.953125  16847.953125
# 2022-12-25 00:00:00+00:00  16847.505859  16847.505859  16847.505859
#
#                                   Close     Adj Close   Volume
# Datetime
# 2022-12-24 00:00:00+00:00  16796.976562  16796.976562        0
# 2022-12-24 00:01:00+00:00  16797.513672  16797.513672        0
# 2022-12-24 00:02:00+00:00  16797.535156  16797.535156        0
# 2022-12-24 00:03:00+00:00  16797.552734  16797.552734        0
# 2022-12-24 00:04:00+00:00  16794.287109  16794.287109        0
# ...                                 ...           ...      ...
# 2022-12-24 23:55:00+00:00  16848.976562  16848.976562  4188160
# 2022-12-24 23:56:00+00:00  16848.990234  16848.990234        0
# 2022-12-24 23:57:00+00:00  16849.703125  16849.703125    36864
# 2022-12-24 23:58:00+00:00  16847.953125  16847.953125        0
# 2022-12-25 00:00:00+00:00  16847.505859  16847.505859   235520
#
# [1430 rows x 6 columns]

# %%
ETH = yf.download('ETH-USD', start='2022-12-24', end='2022-12-25',  interval = '1m')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
ETH
# Out:
#                                   Open         High          Low        Close  \
# Datetime
# 2022-12-24 00:00:00+00:00  1220.117920  1220.117920  1220.117920  1220.117920
# 2022-12-24 00:01:00+00:00  1220.205444  1220.205444  1220.205444  1220.205444
# 2022-12-24 00:02:00+00:00  1220.328491  1220.328491  1220.328491  1220.328491
# 2022-12-24 00:03:00+00:00  1220.246460  1220.246460  1220.246460  1220.246460
# 2022-12-24 00:04:00+00:00  1220.199341  1220.199341  1220.199341  1220.199341
# ...                                ...          ...          ...          ...
# 2022-12-24 23:55:00+00:00  1221.322266  1221.322266  1221.322266  1221.322266
# 2022-12-24 23:56:00+00:00  1221.301636  1221.301636  1221.301636  1221.301636
# 2022-12-24 23:57:00+00:00  1221.290649  1221.290649  1221.290649  1221.290649
# 2022-12-24 23:58:00+00:00  1221.146973  1221.146973  1221.146973  1221.146973
# 2022-12-25 00:00:00+00:00  1221.171509  1221.171509  1221.171509  1221.171509
#
#                              Adj Close  Volume
# Datetime
# 2022-12-24 00:00:00+00:00  1220.117920       0
# 2022-12-24 00:01:00+00:00  1220.205444       0
# 2022-12-24 00:02:00+00:00  1220.328491       0
# 2022-12-24 00:03:00+00:00  1220.246460       0
# 2022-12-24 00:04:00+00:00  1220.199341       0
# ...                                ...     ...
# 2022-12-24 23:55:00+00:00  1221.322266       0
# 2022-12-24 23:56:00+00:00  1221.301636       0
# 2022-12-24 23:57:00+00:00  1221.290649    2304
# 2022-12-24 23:58:00+00:00  1221.146973       0
# 2022-12-25 00:00:00+00:00  1221.171509       0
#
# [1430 rows x 6 columns]

# %%
S1_0 = BTC['Open'][0]
S2_0 = ETH['Open'][0]

# %%
S1_0
# Out:
# 16796.9765625

# %%
S2_0
# Out:
# 1220.117919921875

# %%
lr1 = np.log(BTC['Adj Close'] / BTC['Adj Close'].shift(1))
lr2 = np.log(ETH['Adj Close'] / ETH['Adj Close'].shift(1))
mu_1 = lr1.mean() * 1440
mu_2 = lr2.mean() * 1440
sigma_1 = lr1.std() * np.sqrt(1440)
sigma_2 = lr2.std() * np.sqrt(1440)
rho = 0.85
z_0 = 0.00
gamma = 0.8
delta = 1
T = 1
M = len(BTC)

# %%
result = linregress(np.log(BTC['Adj Close']), np.log(ETH['Adj Close']))
beta = result.slope
beta
# Out:
# 1.053559571256363

# %%
dt = T/M
S1 = np.zeros((M + 1, 1))
S2 = np.zeros((M + 1, 1))
z =  np.zeros((M + 1, 1))
a =  np.zeros((M + 1, 1))
b =  np.zeros((M + 1, 1))
c =  np.zeros((M + 1, 1))
Pi_1 = np.zeros((M + 1, 1))
Pi_2 = np.zeros((M + 1, 1))

# %%
tt = np.linspace(0, 1, M + 1)
z[0] = z_0
S1[0] = S1_0
S2[0] = S2_0
sigma_beta = np.sqrt(sigma_1 ** 2 + beta ** 2 * sigma_2 ** 2 + 2 * beta * sigma_1 * sigma_2 * rho)
eta = (-1/delta) * (mu_1 - sigma_1 ** 2/2 + beta*(mu_2 - sigma_2 ** 2/2))
rn = np.random.standard_normal(z.shape)
rn1 = np.random.standard_normal(S1.shape) 
rn2 = np.random.standard_normal(S2.shape) 
for t in range(1, M + 1):
    z[t] = z[t-1]* (1 - delta * (eta - z[t-1])) * dt + sigma_beta * np.sqrt(dt)*((sigma_1 + beta * sigma_2 * rho)/ sigma_beta * rn1[t] + beta * (sigma_2 * np.sqrt(1-rho ** 2)/sigma_beta) * rn1[t]);
    S1[t] = BTC['Adj Close'][t-1]
    S2[t] = ETH['Adj Close'][t-1]

# %%
plt.figure(figsize=(10, 6))
plt.plot(tt, S1, 'b', lw=1.5, label='BTC')
plt.plot(tt, S2, 'r', lw=1.5, label='ETH')
plt.legend(loc=0)
plt.xlabel('Time')
plt.ylabel('$')
plt.title('Stock Price')
# Out:
# Text(0.5, 1.0, 'Stock Price')

# %%
plt.figure(figsize=(10, 6))
plt.plot(tt, z, 'g', lw=1.5)
plt.xlabel('Time')
plt.ylabel('Rate')
plt.title('z')
# Out:
# Text(0.5, 1.0, 'z')

# %%
for t in range(1, M + 1):
    a[t] = 0.5 * (T - t * dt)/((1-rho ** 2) * sigma_1 ** 2)
    b[t] = - 0.25 * (T - t * dt) ** 2 * (sigma_1 ** 2 + beta * sigma_2 ** 2)/((1 - rho ** 2) * sigma_1 ** 2) - rho * mu_2 * (T - t * dt)/((1 - rho **2) * sigma_1 * sigma_2)
    c[t] = 0.5 * mu_2 ** 2 * (T - t * dt)/((1 - rho ** 2) * sigma_2 ** 2) + 0.25 * (T - t * dt) ** 2 * (sigma_1 ** 2 + beta * sigma_2 ** 2 + 2 * sigma_1 * sigma_2 * beta *rho) * delta ** 2/((1 - rho ** 2) * sigma_1 ** 2) + 0.25 * (T - t * dt) ** 2 * mu_2 * delta * rho * (sigma_1 ** 2 + beta * sigma_2 ** 2) + 1/24 * (T - t * dt) ** 3 * (sigma_1 ** 2 + beta * sigma_2 ** 2) ** 2 * delta ** 2/((1 - rho ** 2) * sigma_1 ** 2)
    Pi_1[t] = (1 / S1[t]) * ((mu_1 + delta * z[t])/(gamma * (1 - rho ** 2) * sigma_1 ** 2) + delta/gamma * (-2 * a[t] * (mu_1 + delta * z[t])-b[t]) - rho * mu_2/(gamma * (1 - rho ** 2) * sigma_1 * sigma_2))
    Pi_2[t] = (1 / S2[t]) * (mu_2 / (gamma * (1 - rho ** 2) * sigma_2 ** 2) + delta * beta / gamma * (- 2 * a[t] * (mu_1 + delta * z[t]) - b[t]) - rho * (mu_1 + delta * z[t]) / (gamma * (1 - rho ** 2) * sigma_1 * sigma_2))

# %%
plt.figure(figsize=(10, 6))
plt.plot(tt, Pi_1, 'b', lw=1.5, label='w1')
plt.plot(tt, Pi_2, 'r', lw=1.5, label='w2')
plt.legend(loc=0)
plt.xlabel('Time')
plt.ylabel('%')
plt.title('Weights')
# Out:
# Text(0.5, 1.0, 'Weights')

# %%
plt.figure(figsize=(10, 6))
plt.plot(tt, Pi_1 * S1, 'b', lw=1.5, label='Wealth 1')
plt.plot(tt, Pi_2 * S2, 'r', lw=1.5, label='Wealth 2')
plt.legend(loc=0)
plt.xlabel('Time')
plt.ylabel('$')
plt.title('Cash')
# Out:
# Text(0.5, 1.0, 'Cash')

# %%
Wealth = abs(Pi_1 * S1) + abs(Pi_2 * S2)

# %%
plt.figure(figsize=(10, 6))
plt.plot(tt[1:], Wealth[1:], 'b', lw=1.5, label='Total')
plt.legend(loc=0)
plt.xlabel('Time')
plt.ylabel('$')
plt.title('Wealth')
# Out:
# Text(0.5, 1.0, 'Wealth')

# %%
Wealth[1]
# Out:
# array([2347.74375596])

# %%
Wealth[-1]
# Out:
# array([2539.63311027])

# %%
(Wealth[-1] - Wealth[1])/Wealth[1]
# Out:
# array([0.08173352])

# %%
mu_1
# Out:
# 0.003026843654085393

# %%
mu_2
# Out:
# 0.0008697855500754747

# %%
sigma_1
# Out:
# 0.0027106278018077606

# %%
sigma_2
# Out:
# 0.0033122667772218476

# %%
plt.figure(figsize=(10, 6))
plt.plot(tt, Pi_1 * S1 + Pi_2 * S2, 'b', lw=1.5, label='Dynamic')
plt.plot(tt, Pi_1.mean() * S1 + Pi_2.mean() * S2, 'r', lw=1.5, label='Static')
plt.legend(loc=0)
plt.xlabel('Time')
plt.ylabel('$')
plt.title('Comparison')
# Out:
# Text(0.5, 1.0, 'Comparison')

# %%
Pi_1.mean()
# Out:
# 0.0442330267795908

# %%
Pi_2.mean()
# Out:
# -1.4071799688447257
